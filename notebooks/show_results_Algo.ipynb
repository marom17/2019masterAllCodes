# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time
import os
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %%
raspberry = "pi1"
path = "dataset/results/"+raspberry
files = []
for file in os.listdir(path):
    if(".csv" in file and "result" in file):
        files.append(file)
print(files)
# Out:
# ['results.csv', 'results0.csv', 'results1.csv', 'results2.csv', 'results3.csv', 'results4.csv', 'results5.csv']

# %%
measures = ["2019-05-13 00-00-01 scd30.csv","2019-05-28 01-00-01 scd30.csv","2019-06-13 01-00-02 scd30.csv",
          "2019-05-20 00-00-01 scd30.csv","2019-06-10 01-00-02 scd30.csv","2019-05-29 01-00-02 scd30.csv"]

dateparse = lambda dates: pd.datetime.strptime(dates, '%Y-%m-%d %H-%M-%S')
data = []
for file in measures:
    data.append(pd.read_csv(path+"/"+file, parse_dates=['Time'], index_col='Time',date_parser=dateparse))
nbData = len(data)
for i in range(0,nbData):
    data[i] = data[i][data[i]["#CO2"]<=7000]

# %%
index = ['Iteration','ARIMA10_5Time','ARIMA10_5Perc','ARIMA10_5Conf','AR10_5Time','AR10_5Perc',
         'ARIMA10_10Time','ARIMA10_10Perc','ARIMA10_10Conf','AR10_10Time','AR10_10Perc',
         'ARIMA10_15Time','ARIMA10_15Perc','ARIMA10_15Conf','AR10_15Time','AR10_15Perc',
         'ARIMA20_5Time','ARIMA20_5Perc','ARIMA20_5Conf','AR20_5Time','AR20_5Perc',
         'ARIMA20_10Time','ARIMA20_10Perc','ARIMA20_10Conf','AR20_10Time','AR20_10Perc',
         'ARIMA20_15Time','ARIMA20_15Perc','ARIMA20_15Conf','AR20_15Time','AR20_15Perc']
tmp = "Iteration,ARIMA10_5Time,ARIMA10_5Perc,ARIMA10_5Conf,AR10_5Time,AR10_5Perc,ARIMA10_10Time,ARIMA10_10Perc,ARIMA10_10Conf,AR10_10Time,AR10_10Perc,ARIMA10_15Time,ARIMA10_15Perc,ARIMA10_15Conf,AR10_15Time,AR10_15Perc,ARIMA20_5Time,ARIMA20_5Perc,ARIMA20_5Conf,AR20_5Time,AR20_5Perc,ARIMA20_10Time,ARIMA20_10Perc,ARIMA20_10Conf,AR20_10Time,AR20_10Perc,ARIMA20_15Time,ARIMA20_15Perc,ARIMA20_15Conf,AR20_15Time,AR20_15Perc"

# %%
results = []
for i in range(1,7):
    results.append(pd.read_csv(path+"/"+files[i]))
    results[i-1] = results[i-1].set_index("Iteration")
print(results[0].head())
# Out:
#            ARIMA10_5Time  ARIMA10_5Perc  ARIMA10_5Conf  AR10_5Time  \
# Iteration
# 0              37.296289            1.0      60.162528    0.002752
# 1               0.768728            1.0      55.640131    0.002583
# 2               1.019001            1.0      55.784969    0.002613
# 3               0.541092            1.0      60.322380    0.002583
# 4               1.884733            1.0      65.604120    0.002565
#
#            AR10_5Perc  ARIMA10_10Time  ARIMA10_10Perc  ARIMA10_10Conf  \
# Iteration
# 0                 1.0       37.312887             1.0      123.329319
# 1                 1.0        0.778447             1.0      108.162790
# 2                 1.0        1.040145             1.0      107.972972
# 3                 1.0        0.546645             1.0      119.382546
# 4                 1.0        1.871431             1.0      137.803839
#
#            AR10_10Time  AR10_10Perc  ...  ARIMA20_10Time  ARIMA20_10Perc  \
# ...

# %%
for i in range(0,len(results)):
    print(measures[i])
    plt.figure()
    plt.plot(data[i])
    plt.show()
    print("ARIMA 10 min buffer and 5 min pred")
    print("Time min: "+str(results[i]["ARIMA10_5Time"].min()))
    print("Time max: "+str(results[i]["ARIMA10_5Time"].max()))
    print("Time median: "+str(results[i]["ARIMA10_5Time"].median()))
    print("Time mean: "+str(results[i]["ARIMA10_5Time"].mean()))
    print("Percent min: "+str(results[i]["ARIMA10_5Perc"].min()))
    print("Percent max: "+str(results[i]["ARIMA10_5Perc"].max()))
    print("Percent median: "+str(results[i]["ARIMA10_5Perc"].median()))
    print("Percent mean: "+str(results[i]["ARIMA10_5Perc"].mean()))
    print("Conf min: "+str(results[i]["ARIMA10_5Conf"].min()))
    print("Conf max: "+str(results[i]["ARIMA10_5Conf"].max()))
    print("Conf median: "+str(results[i]["ARIMA10_5Conf"].median()))
    print("Conf mean: "+str(results[i]["ARIMA10_5Conf"].mean()))
    print("\n")

    print("ARIMA 10 min buffer and 10 min pred")
    print("Time min: "+str(results[i]["ARIMA10_10Time"].min()))
    print("Time max: "+str(results[i]["ARIMA10_10Time"].max()))
    print("Time median: "+str(results[i]["ARIMA10_10Time"].median()))
    print("Time mean: "+str(results[i]["ARIMA10_10Time"].mean()))
    print("Percent min: "+str(results[i]["ARIMA10_10Perc"].min()))
    print("Percent max: "+str(results[i]["ARIMA10_10Perc"].max()))
    print("Percent median: "+str(results[i]["ARIMA10_10Perc"].median()))
    print("Percent mean: "+str(results[i]["ARIMA10_10Perc"].mean()))
    print("Conf min: "+str(results[i]["ARIMA10_10Conf"].min()))
    print("Conf max: "+str(results[i]["ARIMA10_10Conf"].max()))
    print("Conf median: "+str(results[i]["ARIMA10_10Conf"].median()))
    print("Conf mean: "+str(results[i]["ARIMA10_10Conf"].mean()))
    print("\n")

    print("ARIMA 10 min buffer and 15 min pred")
    print("Time min: "+str(results[i]["ARIMA10_15Time"].min()))
    print("Time max: "+str(results[i]["ARIMA10_15Time"].max()))
    print("Time median: "+str(results[i]["ARIMA10_15Time"].median()))
    print("Time mean: "+str(results[i]["ARIMA10_15Time"].mean()))
    print("Percent min: "+str(results[i]["ARIMA10_15Perc"].min()))
    print("Percent max: "+str(results[i]["ARIMA10_15Perc"].max()))
    print("Percent median: "+str(results[i]["ARIMA10_15Perc"].median()))
    print("Percent mean: "+str(results[i]["ARIMA10_15Perc"].mean()))
    print("Conf min: "+str(results[i]["ARIMA10_15Conf"].min()))
    print("Conf max: "+str(results[i]["ARIMA10_15Conf"].max()))
    print("Conf median: "+str(results[i]["ARIMA10_15Conf"].median()))
    print("Conf mean: "+str(results[i]["ARIMA10_15Conf"].mean()))
    print("\n")

    print("ARIMA 20 min buffer and 5 min pred")
    print("Time min: "+str(results[i]["ARIMA20_5Time"].min()))
    print("Time max: "+str(results[i]["ARIMA20_5Time"].max()))
    print("Time median: "+str(results[i]["ARIMA20_5Time"].median()))
    print("Time mean: "+str(results[i]["ARIMA20_5Time"].mean()))
    print("Percent min: "+str(results[i]["ARIMA20_5Perc"].min()))
    print("Percent max: "+str(results[i]["ARIMA20_5Perc"].max()))
    print("Percent median: "+str(results[i]["ARIMA20_5Perc"].median()))
    print("Percent mean: "+str(results[i]["ARIMA20_5Perc"].mean()))
    print("Conf min: "+str(results[i]["ARIMA20_5Conf"].min()))
    print("Conf max: "+str(results[i]["ARIMA20_5Conf"].max()))
    print("Conf median: "+str(results[i]["ARIMA20_5Conf"].median()))
    print("Conf mean: "+str(results[i]["ARIMA20_5Conf"].mean()))
    print("\n")

    print("ARIMA 20 min buffer and 10 min pred")
    print("Time min: "+str(results[i]["ARIMA20_10Time"].min()))
    print("Time max: "+str(results[i]["ARIMA20_10Time"].max()))
    print("Time median: "+str(results[i]["ARIMA20_10Time"].median()))
    print("Time mean: "+str(results[i]["ARIMA20_10Time"].mean()))
    print("Percent min: "+str(results[i]["ARIMA20_10Perc"].min()))
    print("Percent max: "+str(results[i]["ARIMA20_10Perc"].max()))
    print("Percent median: "+str(results[i]["ARIMA20_10Perc"].median()))
    print("Percent mean: "+str(results[i]["ARIMA20_10Perc"].mean()))
    print("Conf min: "+str(results[i]["ARIMA20_10Conf"].min()))
    print("Conf max: "+str(results[i]["ARIMA20_10Conf"].max()))
    print("Conf median: "+str(results[i]["ARIMA20_10Conf"].median()))
    print("Conf mean: "+str(results[i]["ARIMA20_10Conf"].mean()))
    print("\n")

    print("ARIMA 20 min buffer and 15 min pred")
    print("Time min: "+str(results[i]["ARIMA20_15Time"].min()))
    print("Time max: "+str(results[i]["ARIMA20_15Time"].max()))
    print("Time median: "+str(results[i]["ARIMA20_15Time"].median()))
    print("Time mean: "+str(results[i]["ARIMA20_15Time"].mean()))
    print("Percent min: "+str(results[i]["ARIMA20_15Perc"].min()))
    print("Percent max: "+str(results[i]["ARIMA20_15Perc"].max()))
    print("Percent median: "+str(results[i]["ARIMA20_15Perc"].median()))
    print("Percent mean: "+str(results[i]["ARIMA20_15Perc"].mean()))
    print("Conf min: "+str(results[i]["ARIMA20_15Conf"].min()))
    print("Conf max: "+str(results[i]["ARIMA20_15Conf"].max()))
    print("Conf median: "+str(results[i]["ARIMA20_15Conf"].median()))
    print("Conf mean: "+str(results[i]["ARIMA20_15Conf"].mean()))
    print("\n")

    print("AR 10 min buffer and 5 min pred")
    print("Time min: "+str(results[i]["AR10_5Time"].min()))
    print("Time max: "+str(results[i]["AR10_5Time"].max()))
    print("Time median: "+str(results[i]["AR10_5Time"].median()))
    print("Time mean: "+str(results[i]["AR10_5Time"].mean()))
    print("Percent min: "+str(results[i]["AR10_5Perc"].min()))
    print("Percent max: "+str(results[i]["AR10_5Perc"].max()))
    print("Percent median: "+str(results[i]["AR10_5Perc"].median()))
    print("Percent mean: "+str(results[i]["AR10_5Perc"].mean()))
    print("\n")

    print("AR 10 min buffer and 10 min pred")
    print("Time min: "+str(results[i]["AR10_10Time"].min()))
    print("Time max: "+str(results[i]["AR10_10Time"].max()))
    print("Time median: "+str(results[i]["AR10_10Time"].median()))
    print("Time mean: "+str(results[i]["AR10_10Time"].mean()))
    print("Percent min: "+str(results[i]["AR10_10Perc"].min()))
    print("Percent max: "+str(results[i]["AR10_10Perc"].max()))
    print("Percent median: "+str(results[i]["AR10_10Perc"].median()))
    print("Percent mean: "+str(results[i]["AR10_10Perc"].mean()))
    print("\n")

    print("AR 10 min buffer and 15 min pred")
    print("Time min: "+str(results[i]["AR10_15Time"].min()))
    print("Time max: "+str(results[i]["AR10_15Time"].max()))
    print("Time median: "+str(results[i]["AR10_15Time"].median()))
    print("Time mean: "+str(results[i]["AR10_15Time"].mean()))
    print("Percent min: "+str(results[i]["AR10_15Perc"].min()))
    print("Percent max: "+str(results[i]["AR10_15Perc"].max()))
    print("Percent median: "+str(results[i]["AR10_15Perc"].median()))
    print("Percent mean: "+str(results[i]["AR10_15Perc"].mean()))
    print("\n")

    print("AR 20 min buffer and 5 min pred")
    print("Time min: "+str(results[i]["AR20_5Time"].min()))
    print("Time max: "+str(results[i]["AR20_5Time"].max()))
    print("Time median: "+str(results[i]["AR20_5Time"].median()))
    print("Time mean: "+str(results[i]["AR20_5Time"].mean()))
    print("Percent min: "+str(results[i]["AR20_5Perc"].min()))
    print("Percent max: "+str(results[i]["AR20_5Perc"].max()))
    print("Percent median: "+str(results[i]["AR20_5Perc"].median()))
    print("Percent mean: "+str(results[i]["AR20_5Perc"].mean()))
    print("\n")

    print("AR 20 min buffer and 10 min pred")
    print("Time min: "+str(results[i]["AR20_10Time"].min()))
    print("Time max: "+str(results[i]["AR20_10Time"].max()))
    print("Time median: "+str(results[i]["AR20_10Time"].median()))
    print("Time mean: "+str(results[i]["AR20_10Time"].mean()))
    print("Percent min: "+str(results[i]["AR20_10Perc"].min()))
    print("Percent max: "+str(results[i]["AR20_10Perc"].max()))
    print("Percent median: "+str(results[i]["AR20_10Perc"].median()))
    print("Percent mean: "+str(results[i]["AR20_10Perc"].mean()))
    print("\n")

    print("AR 20 min buffer and 15 min pred")
    print("Time min: "+str(results[i]["AR20_15Time"].min()))
    print("Time max: "+str(results[i]["AR20_15Time"].max()))
    print("Time median: "+str(results[i]["AR20_15Time"].median()))
    print("Time mean: "+str(results[i]["AR20_15Time"].mean()))
    print("Percent min: "+str(results[i]["AR20_15Perc"].min()))
    print("Percent max: "+str(results[i]["AR20_15Perc"].max()))
    print("Percent median: "+str(results[i]["AR20_15Perc"].median()))
    print("Percent mean: "+str(results[i]["AR20_15Perc"].mean()))
    print("\n")
    print("\n")
# Out:
# 2019-05-13 00-00-01 scd30.csv
# C:\Users\romai\Anaconda3\envs\pmdarima\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# ARIMA 10 min buffer and 5 min pred
# Time min: 0.20229005813598636
# Time max: 138.46259093284607
# Time median: 1.2165329456329346
# Time mean: 2.7319470955383736
# Percent min: 0.0
# Percent max: 1.0
# Percent median: 1.0
# Percent mean: 0.9002253855278768
# Conf min: 0.0022543757414723586
# Conf max: 156.99284055245482
# Conf median: 45.03717786581161
# Conf mean: 47.8380691156357
#
#
# ARIMA 10 min buffer and 10 min pred
# ...

# %%
#for i in range(0,nbData):
#    data[i] = data[i]["#CO2"]
for d in data:
    plt.figure()
    plt.plot(d)
    plt.ylim(bottom=0)

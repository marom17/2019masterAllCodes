# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %%
data = []
data.append([0.986,0.961,0.952,1,1,0.968,0.999,0.994,0.994,0.996,1,1,0.981,
             0.977,1,0.948,0.999,1,0.958,0.967,0.999,0.996,0.971,0.973,1,1,
             0.982,0.979,1,1,1,1])
data.append([0.983,0.962,0.948,1,1,0.966,1,0.995,0.995,0.995,1,1,0.986,0.978,
             1,0.945,1,1,0.954,0.967,1,0.995,0.969,0.971,1,1,0.983,0.979,1,
             1,1,1])
xlabels = ["Threshold","Threshold mean"]

# %%
fig, ax = plt.subplots(1, sharex=True, gridspec_kw={'hspace': 0})
ax.title.set_text("AR threshold 32 days accuracy")
ax.boxplot(data)
ax.set_ylabel("Percent")
ax.set_xticklabels(xlabels, rotation=45, fontsize=12)
# Out:
# [Text(0, 0, 'Threshold'), Text(0, 0, 'Threshold mean')]
